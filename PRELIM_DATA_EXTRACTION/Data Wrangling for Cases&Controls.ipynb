# %%
import pandas as pd    
df = pd.read_csv('DIAGNOSES_ICD.csv')
df.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM ICD9_CODE
# 0    1297         109   172335      1.0     40301
# 1    1298         109   172335      2.0       486
# 2    1299         109   172335      3.0     58281
# 3    1300         109   172335      4.0      5855
# 4    1301         109   172335      5.0      4254

# %%
df['ROW_ID'].nunique()
# Out:
# 651047

# %%
df['SUBJECT_ID'].nunique()
# Out:
# 46520

# %%
df['HADM_ID'].nunique()
# Out:
# 58976

# %%
df2 = df[df['ICD9_CODE'].isin(['V293', '2930', '2931', '2939', 'V298', '2980', '2981', '2982', '2983', '2984', '2988', '2989', '3483', '34890', '34831', '34839'])]

# %%
df2.head()
# Out:
#      ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM ICD9_CODE
# 196    1656         128   180872      6.0      V293
# 232    1692         133   191817      6.0      2939
# 300     529          66   104518     10.0      V293
# 377     606          74   182637      5.0      V293
# 993     386          49   190539      5.0      2939

# %%
df2['ROW_ID'].nunique()
# Out:
# 2788

# %%
df2['SUBJECT_ID'].nunique()
# Out:
# 2623

# %%
df2['HADM_ID'].nunique()
# Out:
# 2723

# %%
df3 = df[~df['ICD9_CODE'].isin(['V293', '2930', '2931', '2939', 'V298', '2980', '2981', '2982', '2983', '2984', '2988', '2989', '3483', '34890', '34831', '34839'])]

# %%
df3.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM ICD9_CODE
# 0    1297         109   172335      1.0     40301
# 1    1298         109   172335      2.0       486
# 2    1299         109   172335      3.0     58281
# 3    1300         109   172335      4.0      5855
# 4    1301         109   172335      5.0      4254

# %%
df3['ROW_ID'].nunique()
# Out:
# 648259

# %%
df3['SUBJECT_ID'].nunique()
# Out:
# 46520

# %%
df3['HADM_ID'].nunique()
# Out:
# 58976

# %%
df2_HADM_list = df2['HADM_ID'].tolist()

df2_HADM_list
# Out:
# [180872,
#  191817,
#  104518,
#  182637,
#  190539,
#  132761,
#  162774,
#  147469,
#  190159,
#  159503,
#  194340,
#  110545,
#  199280,
#  197273,
#  101828,
#  105694,
#  177171,
#  115414,
#  151418,
#  170452,
#  183693,
#  176690,
#  153072,
#  116367,
#  116719,
#  127873,
#  146163,
#  140547,
#  164142,
#  121760,
#  118519,
#  175952,
#  184231,
#  120775,
#  147152,
#  179120,
#  151107,
#  197763,
#  194198,
#  154525,
#  164579,
#  118695,
#  159277,
#  130732,
#  171540,
#  161256,
#  165244,
#  172465,
#  151184,
#  179013,
#  179013,
#  137220,
#  187426,
#  147064,
#  177899,
#  174714,
#  132240,
#  139634,
#  139634,
#  131207,
#  159112,
#  147179,
#  120530,
#  150030,
#  115463,
#  129349,
#  144830,
#  102458,
#  126865,
#  120236,
#  107939,
#  146436,
#  124867,
#  112739,
#  149534,
#  145005,
#  123355,
#  167723,
#  134414,
#  133793,
#  139229,
#  189501,
#  195634,
#  124250,
#  177901,
#  126804,
#  185653,
#  176442,
#  106108,
#  166473,
# ...

# %%
df3 = df3[~df3['HADM_ID'].isin(df2_HADM_list)]

# %%
df3['ROW_ID'].nunique()
# Out:
# 607879

# %%
df3['SUBJECT_ID'].nunique()
# Out:
# 44674

# %%
df3['HADM_ID'].nunique()
# Out:
# 56253

# %%
df2['Delirium'] = '1'
df2.head()
# Out:
# C:\Users\15129\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#      ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM ICD9_CODE Delirium
# 196    1656         128   180872      6.0      V293        1
# 232    1692         133   191817      6.0      2939        1
# 300     529          66   104518     10.0      V293        1
# 377     606          74   182637      5.0      V293        1
# 993     386          49   190539      5.0      2939        1

# %%
df2['ROW_ID'].nunique()
# Out:
# 2788

# %%
df3['Delirium'] = '0'
df3.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM ICD9_CODE Delirium
# 0    1297         109   172335      1.0     40301        0
# 1    1298         109   172335      2.0       486        0
# 2    1299         109   172335      3.0     58281        0
# 3    1300         109   172335      4.0      5855        0
# 4    1301         109   172335      5.0      4254        0

# %%
df3['ROW_ID'].nunique()
# Out:
# 607879

# %%
df_cases = df2.drop_duplicates(subset="HADM_ID")

# %%
df_cases['ROW_ID'].nunique()
# Out:
# 2723

# %%
df_controls = df3.drop_duplicates(subset="HADM_ID")

# %%
df_controls['ROW_ID'].nunique()
# Out:
# 56253

# %%
df_cases['HADM_ID'].nunique()
# Out:
# 2723

# %%
df_controls['HADM_ID'].nunique()
# Out:
# 56253

# %%
df_controls_sample = df_controls.sample(2723)

# %%
df_controls_sample['HADM_ID'].nunique()
# Out:
# 2723

# %%
df_cases.to_csv('cases.csv', index=False)

# %%
df_controls_sample.to_csv('controls.csv', index=False)
