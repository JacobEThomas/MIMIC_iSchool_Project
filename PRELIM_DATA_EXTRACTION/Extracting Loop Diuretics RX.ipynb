# %%
import pandas as pd    
rx = pd.read_csv('PRESCRIPTIONS.csv', low_memory=False)
rx.head()
# Out:
#     ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID            STARTDATE  \
# 0  2214776           6   107064         NaN  2175-06-11 00:00:00
# 1  2214775           6   107064         NaN  2175-06-11 00:00:00
# 2  2215524           6   107064         NaN  2175-06-11 00:00:00
# 3  2216265           6   107064         NaN  2175-06-11 00:00:00
# 4  2214773           6   107064         NaN  2175-06-11 00:00:00
#
#                ENDDATE DRUG_TYPE            DRUG DRUG_NAME_POE  \
# 0  2175-06-12 00:00:00      MAIN      Tacrolimus    Tacrolimus
# 1  2175-06-12 00:00:00      MAIN        Warfarin      Warfarin
# 2  2175-06-12 00:00:00      MAIN  Heparin Sodium           NaN
# 3  2175-06-12 00:00:00      BASE             D5W           NaN
# 4  2175-06-12 00:00:00      MAIN      Furosemide    Furosemide
#
#   DRUG_NAME_GENERIC FORMULARY_DRUG_CD     GSN          NDC  \
# 0        Tacrolimus             TACR1  021796  469061711.0
# 1          Warfarin             WARF5  006562   56017275.0
# ...

# %%
rx = rx[['HADM_ID','DRUG']]

# %%
rx.head()
# Out:
#    HADM_ID            DRUG
# 0   107064      Tacrolimus
# 1   107064        Warfarin
# 2   107064  Heparin Sodium
# 3   107064             D5W
# 4   107064      Furosemide

# %%
rx["DRUG"]= rx["DRUG"].replace(['Furosemide', 'Bumetanide', 'Ethacrynic acid', 'Ethacrynic Acid', 'Torsemide'], "1")

# %%
rx["DRUG"]= rx["DRUG"].replace(['furosemide', 'bumetanide', 'ethacrynic acid', 'torsemide'], "1")

# %%
rx.head(50)
# Out:
#     HADM_ID                     DRUG
# 0    107064               Tacrolimus
# 1    107064                 Warfarin
# 2    107064           Heparin Sodium
# 3    107064                      D5W
# 4    107064                        1
# 5    107064                 Warfarin
# 6    107064           Heparin Sodium
# 7    107064                      D5W
# 8    107064           Heparin Sodium
# 9    107064                 Warfarin
# 10   107064                      D5W
# 11   107064               Tacrolimus
# 12   107064               Tacrolimus
# 13   107064    Mycophenolate Mofetil
# 14   107064               Tacrolimus
# 15   107064               Tacrolimus
# 16   107064                      D5W
# 17   107064           Heparin Sodium
# 18   107064                 Warfarin
# 19   107064    Mycophenolate Mofetil
# 20   107064               Tacrolimus
# 21   107064               Tacrolimus
# 22   107064              Neutra-Phos
# 23   143045                      D5W
# ...

# %%
rx['DRUG'].value_counts()
# Out:
# Potassium Chloride                             192993
# Insulin                                        143465
# D5W                                            142241
# 1                                              136226
# 0.9% Sodium Chloride                           130147
# NS                                             129731
# Magnesium Sulfate                               90427
# Iso-Osmotic Dextrose                            87005
# Sodium Chloride 0.9%  Flush                     83392
# Acetaminophen                                   78768
# Metoprolol                                      73986
# 5% Dextrose                                     73829
# SW                                              72522
# Morphine Sulfate                                62134
# Metoprolol Tartrate                             59824
# Lorazepam                                       55352
# Calcium Gluconate                               52110
# ...

# %%
X = ['1']
rx.loc[~rx.DRUG.isin(X), 'DRUG'] = '0'

# %%
rx['DRUG'].value_counts()
# Out:
# 0    4020224
# 1     136226
# Name: DRUG, dtype: int64

# %%
rx.head(50)
# Out:
#     HADM_ID DRUG
# 0    107064    0
# 1    107064    0
# 2    107064    0
# 3    107064    0
# 4    107064    1
# 5    107064    0
# 6    107064    0
# 7    107064    0
# 8    107064    0
# 9    107064    0
# 10   107064    0
# 11   107064    0
# 12   107064    0
# 13   107064    0
# 14   107064    0
# 15   107064    0
# 16   107064    0
# 17   107064    0
# 18   107064    0
# 19   107064    0
# 20   107064    0
# 21   107064    0
# 22   107064    0
# 23   143045    0
# 24   143045    0
# 25   143045    0
# 26   143045    0
# 27   143045    0
# 28   143045    0
# 29   143045    0
# 30   143045    0
# 31   143045    0
# 32   143045    0
# 33   143045    0
# 34   143045    0
# 35   143045    0
# 36   143045    0
# 37   143045    0
# 38   143045    0
# 39   143045    0
# 40   143045    0
# 41   143045    0
# 42   143045    0
# 43   143045    0
# 44   143045    0
# 45   143045    0
# 46   143045    0
# 47   143045    0
# 48   143045    0
# 49   143045    0

# %%
rx.to_csv('diuretic.csv', index=False)
